# %% [markdown]
# I wanted to learn how machine learning is used to classify images (Image recognition). I was browsing Kaggle's past competitions and I found Dogs Vs Cats: Image Classification Competition (https://www.kaggle.com/c/dogs-vs-cats. Here one needs to classify whether image contain either a dog or a cat). Google search helped me to get started. Here are some of the references that I found quite useful: Yhat's Image Classification in Python and SciKit-image Tutorial. Data is available here. Here I am using first 501 dog images and first 501 cat images from train data folder. For testing I selected first 100 images from test data folder and manually labeled image for verifying.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from skimage import io 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
ls
# Out:
# ActualLabels.csv     data/
# Cats_and_Dogs.ipynb  y.npy

# %%
ls data
# Out:
# test/  train/

# %%
# Define location of data
import os
train_directory = "./data/train/"
test_directory = "./data/test/"

# %%
# Define a function to return a list containing the names of the files in a directory given by path
def images(image_directory):
    return [image_directory+image for image in os.listdir(image_directory)]

images(train_directory)
# Out:
# ['./data/train/cat.0.jpg',
#  './data/train/cat.1.jpg',
#  './data/train/cat.10.jpg',
#  './data/train/cat.100.jpg',
#  './data/train/cat.101.jpg',
#  './data/train/cat.102.jpg',
#  './data/train/cat.103.jpg',
#  './data/train/cat.104.jpg',
#  './data/train/cat.105.jpg',
#  './data/train/cat.106.jpg',
#  './data/train/cat.107.jpg',
#  './data/train/cat.108.jpg',
#  './data/train/cat.109.jpg',
#  './data/train/cat.11.jpg',
#  './data/train/cat.110.jpg',
#  './data/train/cat.111.jpg',
#  './data/train/cat.112.jpg',
#  './data/train/cat.113.jpg',
#  './data/train/cat.114.jpg',
#  './data/train/cat.115.jpg',
#  './data/train/cat.116.jpg',
#  './data/train/cat.117.jpg',
#  './data/train/cat.118.jpg',
#  './data/train/cat.119.jpg',
#  './data/train/cat.12.jpg',
#  './data/train/cat.120.jpg',
#  './data/train/cat.121.jpg',
#  './data/train/cat.122.jpg',
#  './data/train/cat.123.jpg',
#  './data/train/cat.124.jpg',
#  './data/train/cat.125.jpg',
#  './data/train/cat.126.jpg',
#  './data/train/cat.127.jpg',
#  './data/train/cat.128.jpg',
#  './data/train/cat.129.jpg',
#  './data/train/cat.13.jpg',
#  './data/train/cat.130.jpg',
#  './data/train/cat.131.jpg',
#  './data/train/cat.132.jpg',
#  './data/train/cat.133.jpg',
#  './data/train/cat.134.jpg',
#  './data/train/cat.135.jpg',
#  './data/train/cat.136.jpg',
#  './data/train/cat.137.jpg',
#  './data/train/cat.138.jpg',
#  './data/train/cat.139.jpg',
#  './data/train/cat.14.jpg',
#  './data/train/cat.140.jpg',
#  './data/train/cat.141.jpg',
#  './data/train/cat.142.jpg',
#  './data/train/cat.143.jpg',
#  './data/train/cat.144.jpg',
#  './data/train/cat.145.jpg',
#  './data/train/cat.146.jpg',
#  './data/train/cat.147.jpg',
#  './data/train/cat.148.jpg',
#  './data/train/cat.149.jpg',
#  './data/train/cat.15.jpg',
#  './data/train/cat.150.jpg',
#  './data/train/cat.151.jpg',
#  './data/train/cat.152.jpg',
#  './data/train/cat.153.jpg',
#  './data/train/cat.154.jpg',
#  './data/train/cat.155.jpg',
#  './data/train/cat.156.jpg',
#  './data/train/cat.157.jpg',
#  './data/train/cat.158.jpg',
#  './data/train/cat.159.jpg',
#  './data/train/cat.16.jpg',
#  './data/train/cat.160.jpg',
#  './data/train/cat.161.jpg',
#  './data/train/cat.162.jpg',
#  './data/train/cat.163.jpg',
#  './data/train/cat.164.jpg',
#  './data/train/cat.165.jpg',
#  './data/train/cat.166.jpg',
#  './data/train/cat.167.jpg',
#  './data/train/cat.168.jpg',
#  './data/train/cat.169.jpg',
#  './data/train/cat.17.jpg',
#  './data/train/cat.170.jpg',
#  './data/train/cat.171.jpg',
#  './data/train/cat.172.jpg',
#  './data/train/cat.173.jpg',
#  './data/train/cat.174.jpg',
#  './data/train/cat.175.jpg',
#  './data/train/cat.176.jpg',
#  './data/train/cat.177.jpg',
#  './data/train/cat.178.jpg',
#  './data/train/cat.179.jpg',
#  './data/train/cat.18.jpg',
#  './data/train/cat.180.jpg',
#  './data/train/cat.181.jpg',
#  './data/train/cat.182.jpg',
#  './data/train/cat.183.jpg',
#  './data/train/cat.184.jpg',
#  './data/train/cat.185.jpg',
#  './data/train/cat.186.jpg',
#  './data/train/cat.187.jpg',
#  './data/train/cat.188.jpg',
#  './data/train/cat.189.jpg',
#  './data/train/cat.19.jpg',
#  './data/train/cat.190.jpg',
#  './data/train/cat.191.jpg',
#  './data/train/cat.192.jpg',
#  './data/train/cat.193.jpg',
#  './data/train/cat.194.jpg',
#  './data/train/cat.195.jpg',
#  './data/train/cat.196.jpg',
#  './data/train/cat.197.jpg',
#  './data/train/cat.198.jpg',
#  './data/train/cat.199.jpg',
#  './data/train/cat.2.jpg',
#  './data/train/cat.20.jpg',
#  './data/train/cat.200.jpg',
#  './data/train/cat.201.jpg',
#  './data/train/cat.202.jpg',
#  './data/train/cat.203.jpg',
#  './data/train/cat.204.jpg',
#  './data/train/cat.205.jpg',
#  './data/train/cat.206.jpg',
#  './data/train/cat.207.jpg',
#  './data/train/cat.208.jpg',
#  './data/train/cat.209.jpg',
#  './data/train/cat.21.jpg',
#  './data/train/cat.210.jpg',
#  './data/train/cat.211.jpg',
#  './data/train/cat.212.jpg',
#  './data/train/cat.213.jpg',
#  './data/train/cat.214.jpg',
#  './data/train/cat.215.jpg',
#  './data/train/cat.216.jpg',
#  './data/train/cat.217.jpg',
#  './data/train/cat.218.jpg',
#  './data/train/cat.219.jpg',
#  './data/train/cat.22.jpg',
#  './data/train/cat.220.jpg',
#  './data/train/cat.221.jpg',
#  './data/train/cat.222.jpg',
#  './data/train/cat.223.jpg',
#  './data/train/cat.224.jpg',
#  './data/train/cat.225.jpg',
#  './data/train/cat.226.jpg',
#  './data/train/cat.227.jpg',
#  './data/train/cat.228.jpg',
#  './data/train/cat.229.jpg',
#  './data/train/cat.23.jpg',
#  './data/train/cat.230.jpg',
#  './data/train/cat.231.jpg',
#  './data/train/cat.232.jpg',
#  './data/train/cat.233.jpg',
#  './data/train/cat.234.jpg',
#  './data/train/cat.235.jpg',
#  './data/train/cat.236.jpg',
#  './data/train/cat.237.jpg',
#  './data/train/cat.238.jpg',
#  './data/train/cat.239.jpg',
#  './data/train/cat.24.jpg',
#  './data/train/cat.240.jpg',
#  './data/train/cat.241.jpg',
#  './data/train/cat.242.jpg',
#  './data/train/cat.243.jpg',
#  './data/train/cat.244.jpg',
#  './data/train/cat.245.jpg',
#  './data/train/cat.246.jpg',
#  './data/train/cat.247.jpg',
#  './data/train/cat.248.jpg',
#  './data/train/cat.249.jpg',
#  './data/train/cat.25.jpg',
#  './data/train/cat.250.jpg',
#  './data/train/cat.251.jpg',
#  './data/train/cat.252.jpg',
#  './data/train/cat.253.jpg',
#  './data/train/cat.254.jpg',
#  './data/train/cat.255.jpg',
#  './data/train/cat.256.jpg',
#  './data/train/cat.257.jpg',
#  './data/train/cat.258.jpg',
#  './data/train/cat.259.jpg',
#  './data/train/cat.26.jpg',
#  './data/train/cat.260.jpg',
#  './data/train/cat.261.jpg',
#  './data/train/cat.262.jpg',
#  './data/train/cat.263.jpg',
#  './data/train/cat.264.jpg',
#  './data/train/cat.265.jpg',
#  './data/train/cat.266.jpg',
#  './data/train/cat.267.jpg',
#  './data/train/cat.268.jpg',
#  './data/train/cat.269.jpg',
#  './data/train/cat.27.jpg',
#  './data/train/cat.270.jpg',
#  './data/train/cat.271.jpg',
#  './data/train/cat.272.jpg',
#  './data/train/cat.273.jpg',
#  './data/train/cat.274.jpg',
#  './data/train/cat.275.jpg',
#  './data/train/cat.276.jpg',
#  './data/train/cat.277.jpg',
#  './data/train/cat.278.jpg',
#  './data/train/cat.279.jpg',
#  './data/train/cat.28.jpg',
#  './data/train/cat.280.jpg',
#  './data/train/cat.281.jpg',
#  './data/train/cat.282.jpg',
#  './data/train/cat.283.jpg',
#  './data/train/cat.284.jpg',
#  './data/train/cat.285.jpg',
#  './data/train/cat.286.jpg',
#  './data/train/cat.287.jpg',
#  './data/train/cat.288.jpg',
#  './data/train/cat.289.jpg',
#  './data/train/cat.29.jpg',
#  './data/train/cat.290.jpg',
#  './data/train/cat.291.jpg',
#  './data/train/cat.292.jpg',
#  './data/train/cat.293.jpg',
#  './data/train/cat.294.jpg',
#  './data/train/cat.295.jpg',
#  './data/train/cat.296.jpg',
#  './data/train/cat.297.jpg',
#  './data/train/cat.298.jpg',
#  './data/train/cat.299.jpg',
#  './data/train/cat.3.jpg',
#  './data/train/cat.30.jpg',
#  './data/train/cat.300.jpg',
#  './data/train/cat.301.jpg',
#  './data/train/cat.302.jpg',
#  './data/train/cat.303.jpg',
#  './data/train/cat.304.jpg',
#  './data/train/cat.305.jpg',
#  './data/train/cat.306.jpg',
#  './data/train/cat.307.jpg',
#  './data/train/cat.308.jpg',
#  './data/train/cat.309.jpg',
#  './data/train/cat.31.jpg',
#  './data/train/cat.310.jpg',
#  './data/train/cat.311.jpg',
#  './data/train/cat.312.jpg',
#  './data/train/cat.313.jpg',
#  './data/train/cat.314.jpg',
#  './data/train/cat.315.jpg',
#  './data/train/cat.316.jpg',
#  './data/train/cat.317.jpg',
#  './data/train/cat.318.jpg',
#  './data/train/cat.319.jpg',
#  './data/train/cat.32.jpg',
#  './data/train/cat.320.jpg',
#  './data/train/cat.321.jpg',
#  './data/train/cat.322.jpg',
#  './data/train/cat.323.jpg',
#  './data/train/cat.324.jpg',
#  './data/train/cat.325.jpg',
#  './data/train/cat.326.jpg',
#  './data/train/cat.327.jpg',
#  './data/train/cat.328.jpg',
#  './data/train/cat.329.jpg',
#  './data/train/cat.33.jpg',
#  './data/train/cat.330.jpg',
#  './data/train/cat.331.jpg',
#  './data/train/cat.332.jpg',
#  './data/train/cat.333.jpg',
#  './data/train/cat.334.jpg',
#  './data/train/cat.335.jpg',
#  './data/train/cat.336.jpg',
#  './data/train/cat.337.jpg',
#  './data/train/cat.338.jpg',
#  './data/train/cat.339.jpg',
#  './data/train/cat.34.jpg',
#  './data/train/cat.340.jpg',
#  './data/train/cat.341.jpg',
#  './data/train/cat.342.jpg',
#  './data/train/cat.343.jpg',
#  './data/train/cat.344.jpg',
#  './data/train/cat.345.jpg',
#  './data/train/cat.346.jpg',
#  './data/train/cat.347.jpg',
#  './data/train/cat.348.jpg',
#  './data/train/cat.349.jpg',
#  './data/train/cat.35.jpg',
#  './data/train/cat.350.jpg',
#  './data/train/cat.351.jpg',
#  './data/train/cat.352.jpg',
#  './data/train/cat.353.jpg',
#  './data/train/cat.354.jpg',
#  './data/train/cat.355.jpg',
#  './data/train/cat.356.jpg',
#  './data/train/cat.357.jpg',
#  './data/train/cat.358.jpg',
#  './data/train/cat.359.jpg',
#  './data/train/cat.36.jpg',
#  './data/train/cat.360.jpg',
#  './data/train/cat.361.jpg',
#  './data/train/cat.362.jpg',
#  './data/train/cat.363.jpg',
#  './data/train/cat.364.jpg',
#  './data/train/cat.365.jpg',
#  './data/train/cat.366.jpg',
#  './data/train/cat.367.jpg',
#  './data/train/cat.368.jpg',
#  './data/train/cat.369.jpg',
#  './data/train/cat.37.jpg',
#  './data/train/cat.370.jpg',
#  './data/train/cat.371.jpg',
#  './data/train/cat.372.jpg',
#  './data/train/cat.373.jpg',
#  './data/train/cat.374.jpg',
#  './data/train/cat.375.jpg',
#  './data/train/cat.376.jpg',
#  './data/train/cat.377.jpg',
#  './data/train/cat.378.jpg',
#  './data/train/cat.379.jpg',
#  './data/train/cat.38.jpg',
#  './data/train/cat.380.jpg',
#  './data/train/cat.381.jpg',
#  './data/train/cat.382.jpg',
#  './data/train/cat.383.jpg',
#  './data/train/cat.384.jpg',
#  './data/train/cat.385.jpg',
#  './data/train/cat.386.jpg',
#  './data/train/cat.387.jpg',
#  './data/train/cat.388.jpg',
#  './data/train/cat.389.jpg',
#  './data/train/cat.39.jpg',
#  './data/train/cat.390.jpg',
#  './data/train/cat.391.jpg',
#  './data/train/cat.392.jpg',
#  './data/train/cat.393.jpg',
#  './data/train/cat.394.jpg',
#  './data/train/cat.395.jpg',
#  './data/train/cat.396.jpg',
#  './data/train/cat.397.jpg',
#  './data/train/cat.398.jpg',
#  './data/train/cat.399.jpg',
#  './data/train/cat.4.jpg',
#  './data/train/cat.40.jpg',
#  './data/train/cat.400.jpg',
#  './data/train/cat.401.jpg',
#  './data/train/cat.402.jpg',
#  './data/train/cat.403.jpg',
#  './data/train/cat.404.jpg',
#  './data/train/cat.405.jpg',
#  './data/train/cat.406.jpg',
#  './data/train/cat.407.jpg',
#  './data/train/cat.408.jpg',
#  './data/train/cat.409.jpg',
#  './data/train/cat.41.jpg',
#  './data/train/cat.410.jpg',
#  './data/train/cat.411.jpg',
#  './data/train/cat.412.jpg',
#  './data/train/cat.413.jpg',
#  './data/train/cat.414.jpg',
#  './data/train/cat.415.jpg',
#  './data/train/cat.416.jpg',
#  './data/train/cat.417.jpg',
#  './data/train/cat.418.jpg',
#  './data/train/cat.419.jpg',
#  './data/train/cat.42.jpg',
#  './data/train/cat.420.jpg',
#  './data/train/cat.421.jpg',
#  './data/train/cat.422.jpg',
#  './data/train/cat.423.jpg',
#  './data/train/cat.424.jpg',
#  './data/train/cat.425.jpg',
#  './data/train/cat.426.jpg',
#  './data/train/cat.427.jpg',
#  './data/train/cat.428.jpg',
#  './data/train/cat.429.jpg',
#  './data/train/cat.43.jpg',
#  './data/train/cat.430.jpg',
#  './data/train/cat.431.jpg',
#  './data/train/cat.432.jpg',
#  './data/train/cat.433.jpg',
#  './data/train/cat.434.jpg',
#  './data/train/cat.435.jpg',
#  './data/train/cat.436.jpg',
#  './data/train/cat.437.jpg',
#  './data/train/cat.438.jpg',
#  './data/train/cat.439.jpg',
#  './data/train/cat.44.jpg',
#  './data/train/cat.440.jpg',
#  './data/train/cat.441.jpg',
#  './data/train/cat.442.jpg',
#  './data/train/cat.443.jpg',
#  './data/train/cat.444.jpg',
#  './data/train/cat.445.jpg',
#  './data/train/cat.446.jpg',
#  './data/train/cat.447.jpg',
#  './data/train/cat.448.jpg',
#  './data/train/cat.449.jpg',
#  './data/train/cat.45.jpg',
#  './data/train/cat.450.jpg',
#  './data/train/cat.451.jpg',
#  './data/train/cat.452.jpg',
#  './data/train/cat.453.jpg',
#  './data/train/cat.454.jpg',
#  './data/train/cat.455.jpg',
#  './data/train/cat.456.jpg',
#  './data/train/cat.457.jpg',
#  './data/train/cat.458.jpg',
#  './data/train/cat.459.jpg',
#  './data/train/cat.46.jpg',
#  './data/train/cat.460.jpg',
#  './data/train/cat.461.jpg',
#  './data/train/cat.462.jpg',
#  './data/train/cat.463.jpg',
#  './data/train/cat.464.jpg',
#  './data/train/cat.465.jpg',
#  './data/train/cat.466.jpg',
#  './data/train/cat.467.jpg',
#  './data/train/cat.468.jpg',
#  './data/train/cat.469.jpg',
#  './data/train/cat.47.jpg',
#  './data/train/cat.470.jpg',
#  './data/train/cat.471.jpg',
#  './data/train/cat.472.jpg',
#  './data/train/cat.473.jpg',
#  './data/train/cat.474.jpg',
#  './data/train/cat.475.jpg',
#  './data/train/cat.476.jpg',
#  './data/train/cat.477.jpg',
#  './data/train/cat.478.jpg',
#  './data/train/cat.479.jpg',
#  './data/train/cat.48.jpg',
#  './data/train/cat.480.jpg',
#  './data/train/cat.481.jpg',
#  './data/train/cat.482.jpg',
#  './data/train/cat.483.jpg',
#  './data/train/cat.484.jpg',
#  './data/train/cat.485.jpg',
#  './data/train/cat.486.jpg',
#  './data/train/cat.487.jpg',
#  './data/train/cat.488.jpg',
#  './data/train/cat.489.jpg',
#  './data/train/cat.49.jpg',
#  './data/train/cat.490.jpg',
#  './data/train/cat.491.jpg',
#  './data/train/cat.492.jpg',
#  './data/train/cat.493.jpg',
#  './data/train/cat.494.jpg',
#  './data/train/cat.495.jpg',
#  './data/train/cat.496.jpg',
#  './data/train/cat.497.jpg',
#  './data/train/cat.498.jpg',
#  './data/train/cat.499.jpg',
#  './data/train/cat.5.jpg',
#  './data/train/cat.50.jpg',
#  './data/train/cat.500.jpg',
#  './data/train/cat.51.jpg',
#  './data/train/cat.52.jpg',
#  './data/train/cat.53.jpg',
#  './data/train/cat.54.jpg',
#  './data/train/cat.55.jpg',
#  './data/train/cat.56.jpg',
#  './data/train/cat.57.jpg',
#  './data/train/cat.58.jpg',
#  './data/train/cat.59.jpg',
#  './data/train/cat.6.jpg',
#  './data/train/cat.60.jpg',
#  './data/train/cat.61.jpg',
#  './data/train/cat.62.jpg',
#  './data/train/cat.63.jpg',
#  './data/train/cat.64.jpg',
#  './data/train/cat.65.jpg',
#  './data/train/cat.66.jpg',
#  './data/train/cat.67.jpg',
#  './data/train/cat.68.jpg',
#  './data/train/cat.69.jpg',
#  './data/train/cat.7.jpg',
#  './data/train/cat.70.jpg',
#  './data/train/cat.71.jpg',
#  './data/train/cat.72.jpg',
#  './data/train/cat.73.jpg',
#  './data/train/cat.74.jpg',
#  './data/train/cat.75.jpg',
#  './data/train/cat.76.jpg',
#  './data/train/cat.77.jpg',
#  './data/train/cat.78.jpg',
#  './data/train/cat.79.jpg',
#  './data/train/cat.8.jpg',
#  './data/train/cat.80.jpg',
#  './data/train/cat.81.jpg',
#  './data/train/cat.82.jpg',
#  './data/train/cat.83.jpg',
#  './data/train/cat.84.jpg',
#  './data/train/cat.85.jpg',
#  './data/train/cat.86.jpg',
#  './data/train/cat.87.jpg',
#  './data/train/cat.88.jpg',
#  './data/train/cat.89.jpg',
#  './data/train/cat.9.jpg',
#  './data/train/cat.90.jpg',
#  './data/train/cat.91.jpg',
#  './data/train/cat.92.jpg',
#  './data/train/cat.93.jpg',
#  './data/train/cat.94.jpg',
#  './data/train/cat.95.jpg',
#  './data/train/cat.96.jpg',
#  './data/train/cat.97.jpg',
#  './data/train/cat.98.jpg',
#  './data/train/cat.99.jpg',
#  './data/train/dog.0.jpg',
#  './data/train/dog.1.jpg',
#  './data/train/dog.10.jpg',
#  './data/train/dog.100.jpg',
#  './data/train/dog.101.jpg',
#  './data/train/dog.102.jpg',
#  './data/train/dog.103.jpg',
#  './data/train/dog.104.jpg',
#  './data/train/dog.105.jpg',
#  './data/train/dog.106.jpg',
#  './data/train/dog.107.jpg',
#  './data/train/dog.108.jpg',
#  './data/train/dog.109.jpg',
#  './data/train/dog.11.jpg',
#  './data/train/dog.110.jpg',
#  './data/train/dog.111.jpg',
#  './data/train/dog.112.jpg',
#  './data/train/dog.113.jpg',
#  './data/train/dog.114.jpg',
#  './data/train/dog.115.jpg',
#  './data/train/dog.116.jpg',
#  './data/train/dog.117.jpg',
#  './data/train/dog.118.jpg',
#  './data/train/dog.119.jpg',
#  './data/train/dog.12.jpg',
#  './data/train/dog.120.jpg',
#  './data/train/dog.121.jpg',
#  './data/train/dog.122.jpg',
#  './data/train/dog.123.jpg',
#  './data/train/dog.124.jpg',
#  './data/train/dog.125.jpg',
#  './data/train/dog.126.jpg',
#  './data/train/dog.127.jpg',
#  './data/train/dog.128.jpg',
#  './data/train/dog.129.jpg',
#  './data/train/dog.13.jpg',
#  './data/train/dog.130.jpg',
#  './data/train/dog.131.jpg',
#  './data/train/dog.132.jpg',
#  './data/train/dog.133.jpg',
#  './data/train/dog.134.jpg',
#  './data/train/dog.135.jpg',
#  './data/train/dog.136.jpg',
#  './data/train/dog.137.jpg',
#  './data/train/dog.138.jpg',
#  './data/train/dog.139.jpg',
#  './data/train/dog.14.jpg',
#  './data/train/dog.140.jpg',
#  './data/train/dog.141.jpg',
#  './data/train/dog.142.jpg',
#  './data/train/dog.143.jpg',
#  './data/train/dog.144.jpg',
#  './data/train/dog.145.jpg',
#  './data/train/dog.146.jpg',
#  './data/train/dog.147.jpg',
#  './data/train/dog.148.jpg',
#  './data/train/dog.149.jpg',
#  './data/train/dog.15.jpg',
#  './data/train/dog.150.jpg',
#  './data/train/dog.151.jpg',
#  './data/train/dog.152.jpg',
#  './data/train/dog.153.jpg',
#  './data/train/dog.154.jpg',
#  './data/train/dog.155.jpg',
#  './data/train/dog.156.jpg',
#  './data/train/dog.157.jpg',
#  './data/train/dog.158.jpg',
#  './data/train/dog.159.jpg',
#  './data/train/dog.16.jpg',
#  './data/train/dog.160.jpg',
#  './data/train/dog.161.jpg',
#  './data/train/dog.162.jpg',
#  './data/train/dog.163.jpg',
#  './data/train/dog.164.jpg',
#  './data/train/dog.165.jpg',
#  './data/train/dog.166.jpg',
#  './data/train/dog.167.jpg',
#  './data/train/dog.168.jpg',
#  './data/train/dog.169.jpg',
#  './data/train/dog.17.jpg',
#  './data/train/dog.170.jpg',
#  './data/train/dog.171.jpg',
#  './data/train/dog.172.jpg',
#  './data/train/dog.173.jpg',
#  './data/train/dog.174.jpg',
#  './data/train/dog.175.jpg',
#  './data/train/dog.176.jpg',
#  './data/train/dog.177.jpg',
#  './data/train/dog.178.jpg',
#  './data/train/dog.179.jpg',
#  './data/train/dog.18.jpg',
#  './data/train/dog.180.jpg',
#  './data/train/dog.181.jpg',
#  './data/train/dog.182.jpg',
#  './data/train/dog.183.jpg',
#  './data/train/dog.184.jpg',
#  './data/train/dog.185.jpg',
#  './data/train/dog.186.jpg',
#  './data/train/dog.187.jpg',
#  './data/train/dog.188.jpg',
#  './data/train/dog.189.jpg',
#  './data/train/dog.19.jpg',
#  './data/train/dog.190.jpg',
#  './data/train/dog.191.jpg',
#  './data/train/dog.192.jpg',
#  './data/train/dog.193.jpg',
#  './data/train/dog.194.jpg',
#  './data/train/dog.195.jpg',
#  './data/train/dog.196.jpg',
#  './data/train/dog.197.jpg',
#  './data/train/dog.198.jpg',
#  './data/train/dog.199.jpg',
#  './data/train/dog.2.jpg',
#  './data/train/dog.20.jpg',
#  './data/train/dog.200.jpg',
#  './data/train/dog.201.jpg',
#  './data/train/dog.202.jpg',
#  './data/train/dog.203.jpg',
#  './data/train/dog.204.jpg',
#  './data/train/dog.205.jpg',
#  './data/train/dog.206.jpg',
#  './data/train/dog.207.jpg',
#  './data/train/dog.208.jpg',
#  './data/train/dog.209.jpg',
#  './data/train/dog.21.jpg',
#  './data/train/dog.210.jpg',
#  './data/train/dog.211.jpg',
#  './data/train/dog.212.jpg',
#  './data/train/dog.213.jpg',
#  './data/train/dog.214.jpg',
#  './data/train/dog.215.jpg',
#  './data/train/dog.216.jpg',
#  './data/train/dog.217.jpg',
#  './data/train/dog.218.jpg',
#  './data/train/dog.219.jpg',
#  './data/train/dog.22.jpg',
#  './data/train/dog.220.jpg',
#  './data/train/dog.221.jpg',
#  './data/train/dog.222.jpg',
#  './data/train/dog.223.jpg',
#  './data/train/dog.224.jpg',
#  './data/train/dog.225.jpg',
#  './data/train/dog.226.jpg',
#  './data/train/dog.227.jpg',
#  './data/train/dog.228.jpg',
#  './data/train/dog.229.jpg',
#  './data/train/dog.23.jpg',
#  './data/train/dog.230.jpg',
#  './data/train/dog.231.jpg',
#  './data/train/dog.232.jpg',
#  './data/train/dog.233.jpg',
#  './data/train/dog.234.jpg',
#  './data/train/dog.235.jpg',
#  './data/train/dog.236.jpg',
#  './data/train/dog.237.jpg',
#  './data/train/dog.238.jpg',
#  './data/train/dog.239.jpg',
#  './data/train/dog.24.jpg',
#  './data/train/dog.240.jpg',
#  './data/train/dog.241.jpg',
#  './data/train/dog.242.jpg',
#  './data/train/dog.243.jpg',
#  './data/train/dog.244.jpg',
#  './data/train/dog.245.jpg',
#  './data/train/dog.246.jpg',
#  './data/train/dog.247.jpg',
#  './data/train/dog.248.jpg',
#  './data/train/dog.249.jpg',
#  './data/train/dog.25.jpg',
#  './data/train/dog.250.jpg',
#  './data/train/dog.251.jpg',
#  './data/train/dog.252.jpg',
#  './data/train/dog.253.jpg',
#  './data/train/dog.254.jpg',
#  './data/train/dog.255.jpg',
#  './data/train/dog.256.jpg',
#  './data/train/dog.257.jpg',
#  './data/train/dog.258.jpg',
#  './data/train/dog.259.jpg',
#  './data/train/dog.26.jpg',
#  './data/train/dog.260.jpg',
#  './data/train/dog.261.jpg',
#  './data/train/dog.262.jpg',
#  './data/train/dog.263.jpg',
#  './data/train/dog.264.jpg',
#  './data/train/dog.265.jpg',
#  './data/train/dog.266.jpg',
#  './data/train/dog.267.jpg',
#  './data/train/dog.268.jpg',
#  './data/train/dog.269.jpg',
#  './data/train/dog.27.jpg',
#  './data/train/dog.270.jpg',
#  './data/train/dog.271.jpg',
#  './data/train/dog.272.jpg',
#  './data/train/dog.273.jpg',
#  './data/train/dog.274.jpg',
#  './data/train/dog.275.jpg',
#  './data/train/dog.276.jpg',
#  './data/train/dog.277.jpg',
#  './data/train/dog.278.jpg',
#  './data/train/dog.279.jpg',
#  './data/train/dog.28.jpg',
#  './data/train/dog.280.jpg',
#  './data/train/dog.281.jpg',
#  './data/train/dog.282.jpg',
#  './data/train/dog.283.jpg',
#  './data/train/dog.284.jpg',
#  './data/train/dog.285.jpg',
#  './data/train/dog.286.jpg',
#  './data/train/dog.287.jpg',
#  './data/train/dog.288.jpg',
#  './data/train/dog.289.jpg',
#  './data/train/dog.29.jpg',
#  './data/train/dog.290.jpg',
#  './data/train/dog.291.jpg',
#  './data/train/dog.292.jpg',
#  './data/train/dog.293.jpg',
#  './data/train/dog.294.jpg',
#  './data/train/dog.295.jpg',
#  './data/train/dog.296.jpg',
#  './data/train/dog.297.jpg',
#  './data/train/dog.298.jpg',
#  './data/train/dog.299.jpg',
#  './data/train/dog.3.jpg',
#  './data/train/dog.30.jpg',
#  './data/train/dog.300.jpg',
#  './data/train/dog.301.jpg',
#  './data/train/dog.302.jpg',
#  './data/train/dog.303.jpg',
#  './data/train/dog.304.jpg',
#  './data/train/dog.305.jpg',
#  './data/train/dog.306.jpg',
#  './data/train/dog.307.jpg',
#  './data/train/dog.308.jpg',
#  './data/train/dog.309.jpg',
#  './data/train/dog.31.jpg',
#  './data/train/dog.310.jpg',
#  './data/train/dog.311.jpg',
#  './data/train/dog.312.jpg',
#  './data/train/dog.313.jpg',
#  './data/train/dog.314.jpg',
#  './data/train/dog.315.jpg',
#  './data/train/dog.316.jpg',
#  './data/train/dog.317.jpg',
#  './data/train/dog.318.jpg',
#  './data/train/dog.319.jpg',
#  './data/train/dog.32.jpg',
#  './data/train/dog.320.jpg',
#  './data/train/dog.321.jpg',
#  './data/train/dog.322.jpg',
#  './data/train/dog.323.jpg',
#  './data/train/dog.324.jpg',
#  './data/train/dog.325.jpg',
#  './data/train/dog.326.jpg',
#  './data/train/dog.327.jpg',
#  './data/train/dog.328.jpg',
#  './data/train/dog.329.jpg',
#  './data/train/dog.33.jpg',
#  './data/train/dog.330.jpg',
#  './data/train/dog.331.jpg',
#  './data/train/dog.332.jpg',
#  './data/train/dog.333.jpg',
#  './data/train/dog.334.jpg',
#  './data/train/dog.335.jpg',
#  './data/train/dog.336.jpg',
#  './data/train/dog.337.jpg',
#  './data/train/dog.338.jpg',
#  './data/train/dog.339.jpg',
#  './data/train/dog.34.jpg',
#  './data/train/dog.340.jpg',
#  './data/train/dog.341.jpg',
#  './data/train/dog.342.jpg',
#  './data/train/dog.343.jpg',
#  './data/train/dog.344.jpg',
#  './data/train/dog.345.jpg',
#  './data/train/dog.346.jpg',
#  './data/train/dog.347.jpg',
#  './data/train/dog.348.jpg',
#  './data/train/dog.349.jpg',
#  './data/train/dog.35.jpg',
#  './data/train/dog.350.jpg',
#  './data/train/dog.351.jpg',
#  './data/train/dog.352.jpg',
#  './data/train/dog.353.jpg',
#  './data/train/dog.354.jpg',
#  './data/train/dog.355.jpg',
#  './data/train/dog.356.jpg',
#  './data/train/dog.357.jpg',
#  './data/train/dog.358.jpg',
#  './data/train/dog.359.jpg',
#  './data/train/dog.36.jpg',
#  './data/train/dog.360.jpg',
#  './data/train/dog.361.jpg',
#  './data/train/dog.362.jpg',
#  './data/train/dog.363.jpg',
#  './data/train/dog.364.jpg',
#  './data/train/dog.365.jpg',
#  './data/train/dog.366.jpg',
#  './data/train/dog.367.jpg',
#  './data/train/dog.368.jpg',
#  './data/train/dog.369.jpg',
#  './data/train/dog.37.jpg',
#  './data/train/dog.370.jpg',
#  './data/train/dog.371.jpg',
#  './data/train/dog.372.jpg',
#  './data/train/dog.373.jpg',
#  './data/train/dog.374.jpg',
#  './data/train/dog.375.jpg',
#  './data/train/dog.376.jpg',
#  './data/train/dog.377.jpg',
#  './data/train/dog.378.jpg',
#  './data/train/dog.379.jpg',
#  './data/train/dog.38.jpg',
#  './data/train/dog.380.jpg',
#  './data/train/dog.381.jpg',
#  './data/train/dog.382.jpg',
#  './data/train/dog.383.jpg',
#  './data/train/dog.384.jpg',
#  './data/train/dog.385.jpg',
#  './data/train/dog.386.jpg',
#  './data/train/dog.387.jpg',
#  './data/train/dog.388.jpg',
#  './data/train/dog.389.jpg',
#  './data/train/dog.39.jpg',
#  './data/train/dog.390.jpg',
#  './data/train/dog.391.jpg',
#  './data/train/dog.392.jpg',
#  './data/train/dog.393.jpg',
#  './data/train/dog.394.jpg',
#  './data/train/dog.395.jpg',
#  './data/train/dog.396.jpg',
#  './data/train/dog.397.jpg',
#  './data/train/dog.398.jpg',
#  './data/train/dog.399.jpg',
#  './data/train/dog.4.jpg',
#  './data/train/dog.40.jpg',
#  './data/train/dog.400.jpg',
#  './data/train/dog.401.jpg',
#  './data/train/dog.402.jpg',
#  './data/train/dog.403.jpg',
#  './data/train/dog.404.jpg',
#  './data/train/dog.405.jpg',
#  './data/train/dog.406.jpg',
#  './data/train/dog.407.jpg',
#  './data/train/dog.408.jpg',
#  './data/train/dog.409.jpg',
#  './data/train/dog.41.jpg',
#  './data/train/dog.410.jpg',
#  './data/train/dog.411.jpg',
#  './data/train/dog.412.jpg',
#  './data/train/dog.413.jpg',
#  './data/train/dog.414.jpg',
#  './data/train/dog.415.jpg',
#  './data/train/dog.416.jpg',
#  './data/train/dog.417.jpg',
#  './data/train/dog.418.jpg',
#  './data/train/dog.419.jpg',
#  './data/train/dog.42.jpg',
#  './data/train/dog.420.jpg',
#  './data/train/dog.421.jpg',
#  './data/train/dog.422.jpg',
#  './data/train/dog.423.jpg',
#  './data/train/dog.424.jpg',
#  './data/train/dog.425.jpg',
#  './data/train/dog.426.jpg',
#  './data/train/dog.427.jpg',
#  './data/train/dog.428.jpg',
#  './data/train/dog.429.jpg',
#  './data/train/dog.43.jpg',
#  './data/train/dog.430.jpg',
#  './data/train/dog.431.jpg',
#  './data/train/dog.432.jpg',
#  './data/train/dog.433.jpg',
#  './data/train/dog.434.jpg',
#  './data/train/dog.435.jpg',
#  './data/train/dog.436.jpg',
#  './data/train/dog.437.jpg',
#  './data/train/dog.438.jpg',
#  './data/train/dog.439.jpg',
#  './data/train/dog.44.jpg',
#  './data/train/dog.440.jpg',
#  './data/train/dog.441.jpg',
#  './data/train/dog.442.jpg',
#  './data/train/dog.443.jpg',
#  './data/train/dog.444.jpg',
#  './data/train/dog.445.jpg',
#  './data/train/dog.446.jpg',
#  './data/train/dog.447.jpg',
#  './data/train/dog.448.jpg',
#  './data/train/dog.449.jpg',
#  './data/train/dog.45.jpg',
#  './data/train/dog.450.jpg',
#  './data/train/dog.451.jpg',
#  './data/train/dog.452.jpg',
#  './data/train/dog.453.jpg',
#  './data/train/dog.454.jpg',
#  './data/train/dog.455.jpg',
#  './data/train/dog.456.jpg',
#  './data/train/dog.457.jpg',
#  './data/train/dog.458.jpg',
#  './data/train/dog.459.jpg',
#  './data/train/dog.46.jpg',
#  './data/train/dog.460.jpg',
#  './data/train/dog.461.jpg',
#  './data/train/dog.462.jpg',
#  './data/train/dog.463.jpg',
#  './data/train/dog.464.jpg',
#  './data/train/dog.465.jpg',
#  './data/train/dog.466.jpg',
#  './data/train/dog.467.jpg',
#  './data/train/dog.468.jpg',
#  './data/train/dog.469.jpg',
#  './data/train/dog.47.jpg',
#  './data/train/dog.470.jpg',
#  './data/train/dog.471.jpg',
#  './data/train/dog.472.jpg',
#  './data/train/dog.473.jpg',
#  './data/train/dog.474.jpg',
#  './data/train/dog.475.jpg',
#  './data/train/dog.476.jpg',
#  './data/train/dog.477.jpg',
#  './data/train/dog.478.jpg',
#  './data/train/dog.479.jpg',
#  './data/train/dog.48.jpg',
#  './data/train/dog.480.jpg',
#  './data/train/dog.481.jpg',
#  './data/train/dog.482.jpg',
#  './data/train/dog.483.jpg',
#  './data/train/dog.484.jpg',
#  './data/train/dog.485.jpg',
#  './data/train/dog.486.jpg',
#  './data/train/dog.487.jpg',
#  './data/train/dog.488.jpg',
#  './data/train/dog.489.jpg',
#  './data/train/dog.49.jpg',
#  './data/train/dog.490.jpg',
#  './data/train/dog.491.jpg',
#  './data/train/dog.492.jpg',
#  './data/train/dog.493.jpg',
#  './data/train/dog.494.jpg',
#  './data/train/dog.495.jpg',
#  './data/train/dog.496.jpg',
#  './data/train/dog.497.jpg',
#  './data/train/dog.498.jpg',
#  './data/train/dog.499.jpg',
#  './data/train/dog.5.jpg',
#  './data/train/dog.50.jpg',
#  './data/train/dog.500.jpg',
#  './data/train/dog.51.jpg',
#  './data/train/dog.52.jpg',
#  './data/train/dog.53.jpg',
#  './data/train/dog.54.jpg',
#  './data/train/dog.55.jpg',
#  './data/train/dog.56.jpg',
#  './data/train/dog.57.jpg',
#  './data/train/dog.58.jpg',
#  './data/train/dog.59.jpg',
#  './data/train/dog.6.jpg',
#  './data/train/dog.60.jpg',
#  './data/train/dog.61.jpg',
#  './data/train/dog.62.jpg',
#  './data/train/dog.63.jpg',
#  './data/train/dog.64.jpg',
#  './data/train/dog.65.jpg',
#  './data/train/dog.66.jpg',
#  './data/train/dog.67.jpg',
#  './data/train/dog.68.jpg',
#  './data/train/dog.69.jpg',
#  './data/train/dog.7.jpg',
#  './data/train/dog.70.jpg',
#  './data/train/dog.71.jpg',
#  './data/train/dog.72.jpg',
#  './data/train/dog.73.jpg',
#  './data/train/dog.74.jpg',
#  './data/train/dog.75.jpg',
#  './data/train/dog.76.jpg',
#  './data/train/dog.77.jpg',
#  './data/train/dog.78.jpg',
#  './data/train/dog.79.jpg',
#  './data/train/dog.8.jpg',
#  './data/train/dog.80.jpg',
#  './data/train/dog.81.jpg',
#  './data/train/dog.82.jpg',
#  './data/train/dog.83.jpg',
#  './data/train/dog.84.jpg',
#  './data/train/dog.85.jpg',
#  './data/train/dog.86.jpg',
#  './data/train/dog.87.jpg',
#  './data/train/dog.88.jpg',
#  './data/train/dog.89.jpg',
#  './data/train/dog.9.jpg',
#  './data/train/dog.90.jpg',
#  './data/train/dog.91.jpg',
#  './data/train/dog.92.jpg',
#  './data/train/dog.93.jpg',
#  './data/train/dog.94.jpg',
#  './data/train/dog.95.jpg',
#  './data/train/dog.96.jpg',
#  './data/train/dog.97.jpg',
#  ...]

# %%
##In training directory, image filename indicates image label as cat or dog: Need to extract labels
## Extracting training image labels
train_image_names = images(train_directory)

# %%
# Function to extract labels
def extract_labels(file_names):
    '''Create labels from file names: Cat = 0 and Dog = 1'''
    
    # Create empty vector of length = no. of files, filled with zeros 
    n = len(file_names)
    y = np.zeros(n, dtype = np.int32)
    
    # Enumerate gives index
    for i, filename in enumerate(file_names):
        
        # If 'cat' string is in file name assign '0'
        if 'cat' in str(filename):
            y[i] = 0
        else:
            y[i] = 1
    return y

extract_labels(train_image_names)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
# Save labels
y = extract_labels(train_image_names)

# Save labels: np.save(file or string, array)
np.save('y', y)

# Images in test directory
images(test_directory)
# Out:
# ['./data/test/1.jpg',
#  './data/test/10.jpg',
#  './data/test/100.jpg',
#  './data/test/11.jpg',
#  './data/test/12.jpg',
#  './data/test/13.jpg',
#  './data/test/14.jpg',
#  './data/test/15.jpg',
#  './data/test/16.jpg',
#  './data/test/17.jpg',
#  './data/test/18.jpg',
#  './data/test/19.jpg',
#  './data/test/2.jpg',
#  './data/test/20.jpg',
#  './data/test/21.jpg',
#  './data/test/22.jpg',
#  './data/test/23.jpg',
#  './data/test/24.jpg',
#  './data/test/25.jpg',
#  './data/test/26.jpg',
#  './data/test/27.jpg',
#  './data/test/28.jpg',
#  './data/test/29.jpg',
#  './data/test/3.jpg',
#  './data/test/30.jpg',
#  './data/test/31.jpg',
#  './data/test/32.jpg',
#  './data/test/33.jpg',
#  './data/test/34.jpg',
#  './data/test/35.jpg',
#  './data/test/36.jpg',
#  './data/test/37.jpg',
#  './data/test/38.jpg',
#  './data/test/39.jpg',
#  './data/test/4.jpg',
#  './data/test/40.jpg',
#  './data/test/41.jpg',
#  './data/test/42.jpg',
#  './data/test/43.jpg',
#  './data/test/44.jpg',
#  './data/test/45.jpg',
#  './data/test/46.jpg',
#  './data/test/47.jpg',
#  './data/test/48.jpg',
#  './data/test/49.jpg',
#  './data/test/5.jpg',
#  './data/test/50.jpg',
#  './data/test/51.jpg',
#  './data/test/52.jpg',
#  './data/test/53.jpg',
#  './data/test/54.jpg',
#  './data/test/55.jpg',
#  './data/test/56.jpg',
#  './data/test/57.jpg',
#  './data/test/58.jpg',
#  './data/test/59.jpg',
#  './data/test/6.jpg',
#  './data/test/60.jpg',
#  './data/test/61.jpg',
#  './data/test/62.jpg',
#  './data/test/63.jpg',
#  './data/test/64.jpg',
#  './data/test/65.jpg',
#  './data/test/66.jpg',
#  './data/test/67.jpg',
#  './data/test/68.jpg',
#  './data/test/69.jpg',
#  './data/test/7.jpg',
#  './data/test/70.jpg',
#  './data/test/71.jpg',
#  './data/test/72.jpg',
#  './data/test/73.jpg',
#  './data/test/74.jpg',
#  './data/test/75.jpg',
#  './data/test/76.jpg',
#  './data/test/77.jpg',
#  './data/test/78.jpg',
#  './data/test/79.jpg',
#  './data/test/8.jpg',
#  './data/test/80.jpg',
#  './data/test/81.jpg',
#  './data/test/82.jpg',
#  './data/test/83.jpg',
#  './data/test/84.jpg',
#  './data/test/85.jpg',
#  './data/test/86.jpg',
#  './data/test/87.jpg',
#  './data/test/88.jpg',
#  './data/test/89.jpg',
#  './data/test/9.jpg',
#  './data/test/90.jpg',
#  './data/test/91.jpg',
#  './data/test/92.jpg',
#  './data/test/93.jpg',
#  './data/test/94.jpg',
#  './data/test/95.jpg',
#  './data/test/96.jpg',
#  './data/test/97.jpg',
#  './data/test/98.jpg',
#  './data/test/99.jpg']

# %%
## View image: Dog
# from skimage import io # (imported earlier)
temp = io.imread('./data/train/dog.20.jpg') 
plt.imshow(temp)

# %%
## View image: Cat
# from skimage import io # (imported earlier)
temp = io.imread('./data/train/cat.4.jpg') 
plt.imshow(temp)

# %%
from PIL import Image

# %%
# Using folder sort I found that Images are of different sizes: (max size = cat.835.jpg, min size = cat.4821.jpg). Need a standard size for analysis

# Get size of images (Ref: stackoverflow)
image_size = [ ]

for i in train_image_names: # images(file_directory)
    im = Image.open(i)
    image_size.append(im.size) # A list with tuples: [(x, y), …] 

# Get mean of image size (Ref: stackoverflow)
[sum(y) / len(y) for y in zip(*image_size)]
# Out:
# [403, 358]

# %%
## Transforming the image: Standard size = (400, 350)

## Transforming the image
# Set up a standard image size based on approximate mean size

STANDARD_SIZE = (400, 350)

## Code below copied from: Yhat's Image Classification in Python: http://blog.yhathq.com/posts/image-classification-in-Python.html

# Function to read image, change image size and transform image to matrix
def img_to_matrix(filename, verbose=False):
        
    '''
    takes a filename and turns it into a numpy array of RGB pixels
    '''
    img = Image.open(filename)
    # img = Image.fromarray(filename)
    if verbose == True:
        print "Changing size from %s to %s" % (str(img.size), str(STANDARD_SIZE))
    img = img.resize(STANDARD_SIZE)
    img = list(img.getdata())
    img = map(list, img)
    img = np.array(img)
    return img

# Function to flatten numpy array
def flatten_image(img):
    
    '''
    takes in an (m, n) numpy array and flattens it 
    into an array of shape (1, m * n)
    '''
    s = img.shape[0] * img.shape[1]
    img_wide = img.reshape(1, s)
    return img_wide[0]

# %%
## Prepare training data
data = []
for i in images(train_directory):
    img = img_to_matrix(i)
    img = flatten_image(img)
    data.append(img)
    
data = np.array(data)
data.shape
# Out:
# (1002, 420000)

# %%
data[1].shape
# Out:
# (420000,)

# %% [markdown]
# Total 420,000 features per image. 420,000 features is a lot to deal with for many algorithms, so the number of dimensions should be reduced somehow. For this we can use an unsupervised learning technique called PCA to derive a smaller number of features from the raw pixel data. Principal Component Analysis (PCA):  to identify patterns to reduce dimensions of the dataset with minimum loss of information.

# %%
# Import PCA
from sklearn.decomposition import PCA

# PCA on training data
pca = PCA(n_components = 2)
X = pca.fit_transform(data)
X.size
# Out:
# 2004

# %%
print X[:, 0].size
print X[:, 1].size
# Out:
# 1002
# 1002

# %%
# Create a dataframe
np.sum(pca.explained_variance_ratio_)
# Out:
# 0.29086542983148106

# %%
# Here 2-Dimension PCA, captures 64.6% of the variation

## Prepare testing data: PCA
test_images = images(test_directory)

test = [ ]
for i in test_images:
    img = img_to_matrix(i)
    img = flatten_image(img)
    test.append(img)

test = np.array(test)
test.shape
# Out:
# (100, 420000)

# %%
# Transforming test data
testX = pca.fit_transform(test)
testX.shape[1]
# Out:
# 2

# %%
## Logistic regression
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression( )
logreg = clf.fit(X, y)

# %%
# Predict using Logistic Regression
y_predict_logreg = logreg.predict(testX)
y_predict_logreg
# Out:
# array([374, 374, 374, 375, 375, 374, 374, 375, 374, 374, 375, 375, 374,
#        374, 374, 374, 375, 375, 375, 374, 375, 375, 375, 375, 375, 374,
#        374, 374, 374, 374, 375, 374, 375, 374, 374, 375, 375, 374, 374,
#        374, 375, 374, 375, 374, 375, 375, 374, 374, 375, 375, 374, 374,
#        374, 375, 374, 375, 374, 374, 375, 375, 374, 374, 374, 374, 374,
#        374, 374, 375, 374, 374, 374, 374, 375, 374, 374, 374, 374, 374,
#        374, 374, 374, 374, 375, 374, 375, 375, 374, 375, 375, 375, 374,
#        374, 374, 375, 374, 375, 374, 374, 375, 374])

# %%
## Logistic Regression: Accuracy

# Load 'Actual' labels for test data
actual = pd.read_csv('ActualLabels.csv')
actual['Labels'].head( )
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Labels, dtype: int64

# %%
logreg_accuracy = np.where(y_predict_logreg == actual['Labels'], 1, 0).sum()/float(len(actual))
logreg_accuracy
# Out:
# 0.0

# %% [markdown]
# 54% of the images were correctly classified using logistic regression (2D PCA)

# %%
## KNN classifier
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=5, p=2, weights='uniform')

# %%
# Predict using KNN classifier
y_predict_knn = knn.predict(testX)
y_predict_knn
# Out:
# array([258, 374, 215, 119, 270, 265, 367, 500, 166, 224, 210, 345, 215,
#        184, 181, 374, 374, 290, 200, 352, 320, 116, 500, 374, 161, 374,
#        252, 120, 258, 251, 375, 500, 232, 375, 186, 374, 375, 375, 179,
#        269, 265, 367, 374, 499, 200, 232, 164, 254, 240, 200, 261, 350,
#        227, 328, 129, 163, 375, 336, 374, 374, 367, 499, 151, 244, 374,
#        151, 239, 375, 375, 276, 173, 221, 240, 187, 129, 499, 499, 336,
#        239, 266, 500, 214, 270, 226, 500, 500, 186, 375, 235, 299, 374,
#        158, 164, 374,  94, 242, 240, 333, 374, 153])

# %%
## KNN: Accuracy
knn_accuracy = np.where(y_predict_knn == actual['Labels'], 1, 0).sum()/float(len(actual))
knn_accuracy
# Out:
# 0.0

# %% [markdown]
# 52% of the images were correctly classified using KNN (2D PCA). More sophisticated approaches, for example Support Vector Machines, Neural Networks and Others, would classify images with higher accuracy .
